# %%
print('Hello Jupyter Notebooks')
# Out:
# Hello Jupyter Notebooks

# %% [markdown]
# # Jupyter Notes
#
# jupyter ntoebooks use the `.ipnb` extension
#
# Jupyter shortcuts:
# * shift + enter: runs current cell
# * ESC + y : makes cell `code` mode
# * ESC + m : makes cell `markdown` mode

# %% [markdown]
# ## Bash Commands
# prefix them with `!`

# %%
#!conda list

# %% [markdown]
# ## Magic Commands
# prefix them with `%`
#
# to get the list of magic commands use: `%lsmagic`

# %%
# View magic commands
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# Run Present working directory
# %pwd
# Out:
# '/Users/tuckeringlefield/Documents/GitHub/my-notes-TuckerInglefield/Module2'

# %% [markdown]
# One of the most common magic commands is the `%matplotlib inline` command. This ommand will enable plots to be displayed

# %%
# Enable plots to be displayed
# %matplotlib inline

# %%
"""Simple Demo of scatter plot"""

import numpy as np 
import matplotlib.pyplot as plt

n = 100
x = np.random.rand(n)
y = np.random.rand(n)
colors = np.random.rand(n)

# Calculate the area
area = np.pi* (15*np.random.rand(n))**2 # 0 to 15 point radius

# Plot data
plt.scatter(x,y, s=area, c= colors, alpha=0.5)
plt.title("Jackson Pollock")
plt.show()

# %% [markdown]
# ## HTML
# Magic command to render the cell as `HTML`

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KbHXisXdd2c?si=5iV4YxPSnFN_zZ0b" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KbHXisXdd2c?si=5iV4YxPSnFN_zZ0b" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# # Conda
#
# Create and magage your vitual environments
#
# To create virtual env. with a specific `python` version
# ```
# conda create -n cs4580 python=3.11.5
# ```
#
# To activate your environment run:
# ```
# conda activate cs4580
# or activate cs4580
# ```
#
# To get list of evironments:
# ```
# conda env list
# ```
#
# To install a package:
# ```
# conda install package_name
# ```

# %% [markdown]
# # NumPy
#
# ## Features
# - High performance
# - Vectorization
# - Broadcasting
# - Interoperability

# %% [markdown]
# ### Comparison with other alternatives
#
# ### Python list vs NumPy Arrays
# - Elements of different types `vs` same type
# - Variable size nesting is possible `vs` same size
# - No operations at the list level `vs` operations allowed at the array level
# - Uses a lot of memory `vs` uses less memory
