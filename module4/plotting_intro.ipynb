# %% [markdown]
# ## Intro to plotting

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Dummy data
x = [1,2,3,4,5]
y = [10,20,30,40,50]
print(x)
print(y)
# Out:
# [1, 2, 3, 4, 5]
# [10, 20, 30, 40, 50]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Test data
#
# get the data from `icarus.cs.weber.edu/~hvalle/cs4580/data/plottingDemo01.zip`

# %%
hw_df = pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hw_df = pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# can't access the data right now... will come back to this...

# %% [markdown]
# ## Common plots
# - line
# - scatter
# - bar
# - historgrams
# - area
# - ...

# %%
y = [45, 49, 54, 38, 41]
plt.scatter(x, y)
